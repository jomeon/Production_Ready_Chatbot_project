# %% [markdown]
# # APIS AI - Testy manualne Chatbota
# Poniższy notatnik prezentuje działanie głównej logiki chatbota (`APISChatbot`) połączonej z lokalnym modelem Ollama.
#
# **Wymagania wstępne do uruchomienia:**
# 1. Aktywne środowisko: `conda activate apis_chatbot`
# 2. Uruchomiony w tle silnik Ollama z modelem `llama3` (`ollama run llama3`).

# %%
import sys
import os

sys.path.append(os.path.abspath('..'))

from app.chatbot_core import APISChatbot

print("Inicjalizacja chatbota...")
bot = APISChatbot()
print(f"Chatbot gotowy. Model: {bot.model_name}")
print(f"Bieżąca historia: {bot.history}")
# Out:
# Inicjalizacja chatbota...
# Chatbot gotowy. Model: llama3
# Bieżąca historia: [{'role': 'system', 'content': 'Jesteś profesjonalnym i pomocnym asystentem AI. Odpowiadaj zwięźle, rzeczowo i zawsze w języku polskim.'}]

# %%
pytanie_1 = "Cześć, wymień 3 najpopularniejsze języki programowania."
print(f"Użytkownik: {pytanie_1}")

odpowiedz_1 = bot.generate_response(pytanie_1, temperature=0.5)
print(f"\nAPIS Bot:\n{odpowiedz_1}")
# Out:
# Użytkownik: Cześć, wymień 3 najpopularniejsze języki programowania.
#
# APIS Bot:
# Witaj!
#
# Trzy najpopularniejsze języki programowania to:
#
# 1. Java
# 2. Python
# 3. JavaScript

# %%
pytanie_2 = "Z tych trzech, który jest najlepszy do analizy danych?"
print(f"Użytkownik: {pytanie_2}")

odpowiedz_2 = bot.generate_response(pytanie_2, temperature=0.7)
print(f"\nAPIS Bot:\n{odpowiedz_2}")
# Out:
# Użytkownik: Z tych trzech, który jest najlepszy do analizy danych?
#
# APIS Bot:
# Python to jeden z najlepiej sprawdzonych języków programowania do analizy danych! Dlatego, że:
#
# * Istnieje wiele bibliotek i frameworków, takich jak Pandas, NumPy, scikit-learn i Matplotlib, które są specjalizowane w analiza danych.
# * Python jest łatwy w użyciu i ma prostą syntezę kodu, co czyni go idealnym do analizy danych.
# * Istnieje wiele narzędzi i bibliotek, które mogą pomóc w podejmowaniu decyzji na podstawie danych.
#
# Warto dodać, że Python jest także popularny wśród data scientistów i analityków, a jego społeczność jest bardzo aktywna.

# %%
import json
print(json.dumps(bot.history, indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "role": "system",
#     "content": "Jesteś profesjonalnym i pomocnym asystentem AI. Odpowiadaj zwięźle, rzeczowo i zawsze w języku polskim."
#   },
#   {
#     "role": "user",
#     "content": "Cześć, wymień 3 najpopularniejsze języki programowania."
#   },
#   {
#     "role": "assistant",
#     "content": "Witaj!\n\nTrzy najpopularniejsze języki programowania to:\n\n1. Java\n2. Python\n3. JavaScript"
#   },
#   {
#     "role": "user",
#     "content": "Z tych trzech, który jest najlepszy do analizy danych?"
#   },
#   {
#     "role": "assistant",
#     "content": "Python to jeden z najlepiej sprawdzonych języków programowania do analizy danych! Dlatego, że:\n\n* Istnieje wiele bibliotek i frameworków, takich jak Pandas, NumPy, scikit-learn i Matplotlib, które są specjalizowane w analiza danych.\n* Python jest łatwy w użyciu i ma prostą syntezę kodu, co czyni go idealnym do analizy danych.\n* Istnieje wiele narzędzi i bibliotek, które mogą pomóc w podejmowaniu decyzji na podstawie danych.\n\nWarto dodać, że Python jest także popularny wśród data scientistów i analityków, a jego społeczność jest bardzo aktywna."
#   }
# ]
